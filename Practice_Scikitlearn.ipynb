# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

X,y = make_blobs(n_samples = 200, n_features = 2, centers = 3, random_state = 23)

fig = plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans

X,y = load_iris(return_X_y=True)

#Find optimum number of cluster
sse = [] #SUM  OF SQUARED ERROR
for k in range(3,15):
  km = KMeans(n_clusters=k, random_state=2)
  km.fit(X)
  sse.append(km.inertia_)

sns.set_style("whitegrid")
g=sns.lineplot(x=range(3,15), y=sse)

g.set(xlabel = "Number fo cluster (k)",
      ylabel = "Sum Squared Error",
      title = 'Elbow Method')
plt.show()

# %%
kmeans = KMeans(n_clusters= 3, random_state= 2)
kmeans.fit(X)

pred = kmeans.fit_predict(X)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.scatter(X[:,0],X[:,1], c= pred, cmap =cm.Accent)
plt.grid(True)
for center in kmeans.cluster_centers_:
  center = center[:2]
  plt.scatter(center[0],center[1],marker = '^',c = 'red')
plt.xlabel("petal length (cm)")
plt.ylabel("petal width (cm)")

plt.subplot(1,2,2)
plt.scatter(X[:,2],X[:,3],c = pred, cmap =cm.Accent)
plt.grid(True)
for center in kmeans.cluster_centers_:
  center = center[2:4]
  plt.scatter(center[0],center[1],marker = '^',c = 'red')
plt.xlabel("sepal length (cm)")
plt.ylabel("sepal width (cm)")
plt.show()

# %%
plt.subplot(2,3,4)
plt.scatter(X[:,2],X[:,3],c = pred, cmap =cm.Accent)
plt.grid(True)
for center in kmeans.cluster_centers_:
  center = center[3:5]
  plt.scatter(center[0],center[1],marker = '^',c = 'red')
plt.xlabel("tepal length (cm)")
plt.ylabel("tepal width (cm)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-afff0189b3e6> in <cell line: 4>()
#       4 for center in kmeans.cluster_centers_:
#       5   center = center[3:5]
# ----> 6   plt.scatter(center[0],center[1],marker = '^',c = 'red')
#       7 plt.xlabel("tepal length (cm)")
#       8 plt.ylabel("tepal width (cm)")
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
